# %% [markdown]
# # 06F - CatBoost Classifier (Execution-Ready)
#
# Optimized professional notebook. Run **Run All** to generate and save outputs.

# %%
import pandas as pd
import joblib
import matplotlib.pyplot as plt

from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, classification_report,
    ConfusionMatrixDisplay, RocCurveDisplay,
    PrecisionRecallDisplay
)

df = pd.read_csv("../data/datasets/american_bankruptcy.csv")
df["target"] = df["status_label"].map({"alive": 0, "failed": 1})

display(df.head())
print(df.shape)
# Out:
#   company_name status_label  year       X1       X2      X3      X4       X5  \
# 0          C_1        alive  1999  511.267  833.107  18.373  89.031  336.018
# 1          C_1        alive  2000  485.856  713.811  18.577  64.367  320.590
# 2          C_1        alive  2001  436.656  526.477  22.496  27.207  286.588
# 3          C_1        alive  2002  396.412  496.747  27.172  30.745  259.954
# 4          C_1        alive  2003  432.204  523.302  26.680  47.491  247.245
#
#        X6       X7  ...      X10      X11     X12      X13      X14      X15  \
# 0  35.163  128.348  ...  740.998  180.447  70.658  191.226  163.816  201.026
# 1  18.531  115.187  ...  701.854  179.987  45.790  160.444  125.392  204.065
# 2 -58.939   77.528  ...  710.199  217.699   4.711  112.244  150.464  139.603
# 3 -12.410   66.322  ...  686.621  164.658   3.573  109.590  203.575  124.106
# 4   3.504  104.661  ...  709.292  248.666  20.811  128.656  131.261  131.884
#
#         X16      X17      X18  target
# 0  1024.333  401.483  935.302       0
# 1   874.255  361.642  809.888       0
# 2   638.721  399.964  611.514       0
# 3   606.337  391.633  575.592       0
# 4   651.958  407.608  604.467       0
#
# [5 rows x 22 columns]
# (78682, 22)

# %% [markdown]
# ## Data Preparation

# %%
drop_cols = ["status_label", "target"]
if "company_name" in df.columns:
    drop_cols.append("company_name")

X = df.drop(columns=drop_cols)
y = df["target"]

num = X.select_dtypes(include="number").columns
cat = X.select_dtypes(exclude="number").columns

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

preprocessor = ColumnTransformer([
    ("num", SimpleImputer(strategy="median"), num),
    ("cat", "passthrough", cat)
])

# %% [markdown]
# ## Train CatBoost Model

# %%
model = Pipeline([
    ("preprocessor", preprocessor),
    ("classifier", CatBoostClassifier(
        iterations=100,
        learning_rate=0.1,
        depth=6,
        loss_function="Logloss",
        eval_metric="AUC",
        random_seed=42,
        verbose=0
    ))
])

model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   SimpleImputer(strategy='median'),
#                                                   Index(['year', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10',
#        'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18'],
#       dtype='str')),
#                                                  ('cat', 'passthrough',
#                                                   Index([], dtype='str'))])),
#                 ('classifier',
#                  CatBoostClassifier(depth=6, eval_metric='AUC', iterations=100, learning_rate=0.1, loss_function='Logloss', random_seed=42, verbose=0))])

# %% [markdown]
# ## Cross Validation

# %%
cv = cross_validate(
    model,
    X_train,
    y_train,
    cv=3,
    scoring=["accuracy", "precision", "recall", "f1", "roc_auc"]
)

display(pd.DataFrame(cv).describe())
# Out:
#        fit_time  score_time  test_accuracy  test_precision  test_recall  \
# count  3.000000    3.000000       3.000000        3.000000     3.000000
# mean   1.095884    0.059342       0.934292        0.725381     0.016044
# std    0.038666    0.001260       0.000227        0.104307     0.000830
# min    1.063844    0.058131       0.934036        0.605263     0.015086
# 25%    1.074410    0.058691       0.934204        0.691520     0.015805
# 50%    1.084975    0.059250       0.934372        0.777778     0.016523
# 75%    1.111903    0.059948       0.934420        0.785441     0.016523
# max    1.138832    0.060645       0.934468        0.793103     0.016523
#
#         test_f1  test_roc_auc
# count  3.000000      3.000000
# mean   0.031379      0.778051
# std    0.001546      0.011306
# min    0.029598      0.771184
# 25%    0.030883      0.771527
# 50%    0.032168      0.771870
# 75%    0.032270      0.781485
# max    0.032372      0.791100

# %% [markdown]
# ## Model Evaluation

# %%
pred = model.predict(X_test)
prob = model.predict_proba(X_test)[:, 1]

metrics = pd.DataFrame({
    "Metric": ["Accuracy", "Precision", "Recall", "F1", "ROC-AUC"],
    "Value": [
        accuracy_score(y_test, pred),
        precision_score(y_test, pred),
        recall_score(y_test, pred),
        f1_score(y_test, pred),
        roc_auc_score(y_test, prob)
    ]
})

display(metrics)
print(classification_report(y_test, pred))
# Out:
#       Metric     Value
# 0   Accuracy  0.934676
# 1  Precision  0.785714
# 2     Recall  0.021073
# 3         F1  0.041045
# 4    ROC-AUC  0.788217
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97     14693
#            1       0.79      0.02      0.04      1044
#
#     accuracy                           0.93     15737
#    macro avg       0.86      0.51      0.50     15737
# weighted avg       0.93      0.93      0.90     15737

# %% [markdown]
# ## Visualizations

# %%
ConfusionMatrixDisplay.from_predictions(y_test, pred)
plt.show()

RocCurveDisplay.from_predictions(y_test, prob)
plt.show()

PrecisionRecallDisplay.from_predictions(y_test, prob)
plt.show()

# %% [markdown]
# ## Feature Importance

# %%
cat_model = model.named_steps["classifier"]

importance = pd.DataFrame({
    "Feature": list(num) + list(cat),
    "Importance": cat_model.feature_importances_[:len(num)+len(cat)]
}).sort_values("Importance", ascending=False)

display(importance.head(20))
# Out:
#    Feature  Importance
# 0     year   20.758476
# 8       X8   13.825791
# 11     X11    7.281096
# 5       X5    6.253196
# 6       X6    6.224668
# 3       X3    5.809923
# 15     X15    5.088522
# 7       X7    4.421868
# 1       X1    4.397837
# 18     X18    4.065070
# 17     X17    4.062735
# 2       X2    3.058303
# 13     X13    2.856271
# 14     X14    2.769653
# 12     X12    2.599364
# 10     X10    2.512510
# 4       X4    1.790285
# 16     X16    1.144259
# 9       X9    1.080173

# %% [markdown]
# ## Save Model

# %%
joblib.dump(model, "catboost_model.joblib")
print("Saved catboost_model.joblib")
# Out:
# Saved catboost_model.joblib
