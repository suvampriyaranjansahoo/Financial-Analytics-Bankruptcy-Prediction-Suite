# %% [markdown]
# # 06C - Random Forest Classifier
#
# Professional notebook for training and evaluating a Random Forest model.

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import joblib
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, classification_report,
    confusion_matrix, ConfusionMatrixDisplay,
    RocCurveDisplay, PrecisionRecallDisplay
)

# %% [markdown]
# ## 2. Load Dataset

# %%
df = pd.read_csv("../data/datasets/american_bankruptcy.csv")
df["target"] = df["status_label"].map({"alive":0,"failed":1})
display(df.head())
# Out:
#   company_name status_label  year       X1       X2      X3      X4       X5  \
# 0          C_1        alive  1999  511.267  833.107  18.373  89.031  336.018
# 1          C_1        alive  2000  485.856  713.811  18.577  64.367  320.590
# 2          C_1        alive  2001  436.656  526.477  22.496  27.207  286.588
# 3          C_1        alive  2002  396.412  496.747  27.172  30.745  259.954
# 4          C_1        alive  2003  432.204  523.302  26.680  47.491  247.245
#
#        X6       X7  ...      X10      X11     X12      X13      X14      X15  \
# 0  35.163  128.348  ...  740.998  180.447  70.658  191.226  163.816  201.026
# 1  18.531  115.187  ...  701.854  179.987  45.790  160.444  125.392  204.065
# 2 -58.939   77.528  ...  710.199  217.699   4.711  112.244  150.464  139.603
# 3 -12.410   66.322  ...  686.621  164.658   3.573  109.590  203.575  124.106
# 4   3.504  104.661  ...  709.292  248.666  20.811  128.656  131.261  131.884
#
#         X16      X17      X18  target
# ...

# %% [markdown]
# ## 3. Prepare Features

# %%
drop_cols=["status_label","target"]
if "company_name" in df.columns:
    drop_cols.append("company_name")

X=df.drop(columns=drop_cols)
y=df["target"]

num=X.select_dtypes(include="number").columns
cat=X.select_dtypes(exclude="number").columns

# %% [markdown]
# ## 4. Train/Test Split

# %%
X_train,X_test,y_train,y_test=train_test_split(
    X,y,test_size=0.2,
    stratify=y,
    random_state=42
)

# %% [markdown]
# ## 5. Build Preprocessing Pipeline

# %%
preprocessor=ColumnTransformer([
("num",SimpleImputer(strategy="median"),num),
("cat",Pipeline([
("imputer",SimpleImputer(strategy="most_frequent")),
("encoder",OneHotEncoder(handle_unknown="ignore"))
]),cat)
])

# %% [markdown]
# ## 6. Initialize Random Forest

# %%
model=Pipeline([
("preprocessor",preprocessor),
("classifier",RandomForestClassifier(
    n_estimators=150,
    max_depth=12,
    min_samples_leaf=5,
    class_weight="balanced",
    random_state=42,
    n_jobs=1
))
])

# %% [markdown]
# ## 7. Train Model

# %%
model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   SimpleImputer(strategy='median'),
#                                                   Index(['year', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10',
#        'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18'],
#       dtype='str')),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   Index([], dtype='str'))])),
#                 ('classifier',
# ...

# %% [markdown]
# ## 8. Cross Validation

# %%
scores=cross_val_score(model,X_train,y_train,cv=3,scoring="f1",n_jobs=1)
print(scores)
print("Mean F1:",scores.mean())
# Out:
# [0.31748466 0.31457128 0.29357313]
# Mean F1: 0.3085430232177279

# %% [markdown]
# ## 9. Predictions

# %%
pred=model.predict(X_test)
proba=model.predict_proba(X_test)[:,1]

# %% [markdown]
# ## 10. Evaluation

# %%
results=pd.DataFrame({
"Metric":["Accuracy","Precision","Recall","F1","ROC-AUC"],
"Score":[
accuracy_score(y_test,pred),
precision_score(y_test,pred),
recall_score(y_test,pred),
f1_score(y_test,pred),
roc_auc_score(y_test,proba)
]})
display(results)
print(classification_report(y_test,pred))
# Out:
#       Metric     Score
# 0   Accuracy  0.865222
# 1  Precision  0.250348
# 2     Recall  0.517241
# 3         F1  0.337395
# 4    ROC-AUC  0.833239
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.92     14693
#            1       0.25      0.52      0.34      1044
#
#     accuracy                           0.87     15737
#    macro avg       0.61      0.70      0.63     15737
# weighted avg       0.92      0.87      0.89     15737

# %% [markdown]
# ## 11. Confusion Matrix

# %%
ConfusionMatrixDisplay.from_predictions(y_test,pred)
plt.show()

# %% [markdown]
# ## 12. ROC Curve

# %%
RocCurveDisplay.from_predictions(y_test,proba)
plt.show()

# %% [markdown]
# ## 13. Precision-Recall Curve

# %%
PrecisionRecallDisplay.from_predictions(y_test,proba)
plt.show()

# %% [markdown]
# ## 14. Feature Importance

# %%
rf=model.named_steps["classifier"]
feat=list(num)
if len(cat)>0:
    feat.extend(model.named_steps["preprocessor"].named_transformers_["cat"].named_steps["encoder"].get_feature_names_out(cat))
imp=pd.DataFrame({"Feature":feat,"Importance":rf.feature_importances_})
display(imp.sort_values("Importance",ascending=False).head(20))
# Out:
#    Feature  Importance
# 0     year    0.107220
# 6       X6    0.085844
# 8       X8    0.085231
# 15     X15    0.060080
# 11     X11    0.058426
# 17     X17    0.054653
# 3       X3    0.054012
# 7       X7    0.048379
# 1       X1    0.048291
# 12     X12    0.047277
# 13     X13    0.044770
# 2       X2    0.042233
# 4       X4    0.040969
# 14     X14    0.039778
# 10     X10    0.039695
# 5       X5    0.039552
# 18     X18    0.038008
# 16     X16    0.033613
# 9       X9    0.031968

# %% [markdown]
# ## 15. Save Model

# %%
joblib.dump(model,"random_forest_model.joblib")
# Out:
# ['random_forest_model.joblib']

# %% [markdown]
# ## 16. Business Interpretation

# %%
print("- Random Forest captures nonlinear relationships.")
print("- Compare its F1 and ROC-AUC with previous models.")
print("- High-importance features can guide financial risk analysis.")
# Out:
# - Random Forest captures nonlinear relationships.
# - Compare its F1 and ROC-AUC with previous models.
# - High-importance features can guide financial risk analysis.
