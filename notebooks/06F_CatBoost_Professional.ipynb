# %% [markdown]
# # 06F - CatBoost Classifier
#
# Professional notebook for training and evaluating a CatBoost model.

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import joblib
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, roc_auc_score, classification_report,
    ConfusionMatrixDisplay, RocCurveDisplay,
    PrecisionRecallDisplay
)
from catboost import CatBoostClassifier

# %% [markdown]
# ## 2. Load Dataset

# %%
df=pd.read_csv("../data/datasets/american_bankruptcy.csv")
df["target"]=df["status_label"].map({"alive":0,"failed":1})
display(df.head())
# Out:
#   company_name status_label  year       X1       X2      X3      X4       X5  \
# 0          C_1        alive  1999  511.267  833.107  18.373  89.031  336.018
# 1          C_1        alive  2000  485.856  713.811  18.577  64.367  320.590
# 2          C_1        alive  2001  436.656  526.477  22.496  27.207  286.588
# 3          C_1        alive  2002  396.412  496.747  27.172  30.745  259.954
# 4          C_1        alive  2003  432.204  523.302  26.680  47.491  247.245
#
#        X6       X7  ...      X10      X11     X12      X13      X14      X15  \
# 0  35.163  128.348  ...  740.998  180.447  70.658  191.226  163.816  201.026
# 1  18.531  115.187  ...  701.854  179.987  45.790  160.444  125.392  204.065
# 2 -58.939   77.528  ...  710.199  217.699   4.711  112.244  150.464  139.603
# 3 -12.410   66.322  ...  686.621  164.658   3.573  109.590  203.575  124.106
# 4   3.504  104.661  ...  709.292  248.666  20.811  128.656  131.261  131.884
#
#         X16      X17      X18  target
# ...

# %% [markdown]
# ## 3. Prepare Features

# %%
drop_cols=["status_label","target"]
if "company_name" in df.columns:
    drop_cols.append("company_name")
X=df.drop(columns=drop_cols)
y=df["target"]

num=X.select_dtypes(include="number").columns
cat=X.select_dtypes(exclude="number").columns

# %% [markdown]
# ## 4. Train/Test Split

# %%
X_train,X_test,y_train,y_test=train_test_split(
    X,y,test_size=0.2,stratify=y,random_state=42)

# %% [markdown]
# ## 5. Build Preprocessing Pipeline

# %%
preprocessor=ColumnTransformer([
("num",SimpleImputer(strategy="median"),num),
("cat","passthrough",cat)
])

# %% [markdown]
# ## 6. Initialize CatBoost

# %%
model=Pipeline([
("preprocessor",preprocessor),
("classifier",CatBoostClassifier(
    iterations=300,
    learning_rate=0.05,
    depth=6,
    loss_function="Logloss",
    eval_metric="AUC",
    verbose=0,
    random_seed=42
))
])

# %% [markdown]
# ## 7. Train Model

# %%
model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   SimpleImputer(strategy='median'),
#                                                   Index(['year', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9', 'X10',
#        'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18'],
#       dtype='str')),
#                                                  ('cat', 'passthrough',
#                                                   Index([], dtype='str'))])),
#                 ('classifier',
#                  CatBoostClassifier(depth=6, eval_metric='AUC', iterations=300, learning_rate=0.05, loss_function='Logloss', random_seed=42, verbose=0))])

# %% [markdown]
# ## 8. Cross Validation

# %%
scores=cross_val_score(model,X_train,y_train,cv=5,scoring="f1")
print(scores)
print("Mean F1:",scores.mean())
# Out:
# [0.06666667 0.06264501 0.07126437 0.06385405 0.05740528]
# Mean F1: 0.06436707505202018

# %% [markdown]
# ## 9. Predictions

# %%
pred=model.predict(X_test)
proba=model.predict_proba(X_test)[:,1]

# %% [markdown]
# ## 10. Evaluation Metrics

# %%
results=pd.DataFrame({
"Metric":["Accuracy","Precision","Recall","F1","ROC-AUC"],
"Score":[
accuracy_score(y_test,pred),
precision_score(y_test,pred),
recall_score(y_test,pred),
f1_score(y_test,pred),
roc_auc_score(y_test,proba)]
})
display(results)
print(classification_report(y_test,pred))
# Out:
#       Metric     Score
# 0   Accuracy  0.935629
# 1  Precision  0.781818
# 2     Recall  0.041188
# 3         F1  0.078253
# 4    ROC-AUC  0.814430
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     14693
#            1       0.78      0.04      0.08      1044
#
#     accuracy                           0.94     15737
#    macro avg       0.86      0.52      0.52     15737
# weighted avg       0.93      0.94      0.91     15737

# %% [markdown]
# ## 11. Confusion Matrix

# %%
ConfusionMatrixDisplay.from_predictions(y_test,pred)
plt.show()

# %% [markdown]
# ## 12. ROC Curve

# %%
RocCurveDisplay.from_predictions(y_test,proba)
plt.show()

# %% [markdown]
# ## 13. Precision-Recall Curve

# %%
PrecisionRecallDisplay.from_predictions(y_test,proba)
plt.show()

# %% [markdown]
# ## 14. Feature Importance

# %%
clf=model.named_steps["classifier"]
imp=pd.DataFrame({
    "Feature":num.tolist()+cat.tolist(),
    "Importance":clf.feature_importances_[:len(num)+len(cat)]
})
display(imp.sort_values("Importance",ascending=False).head(20))
# Out:
#    Feature  Importance
# 0     year   19.399073
# 8       X8   11.662173
# 11     X11    6.557151
# 5       X5    6.378305
# 3       X3    6.268862
# 15     X15    5.828393
# 6       X6    5.247492
# 7       X7    4.602389
# 13     X13    4.343114
# 17     X17    4.255570
# 1       X1    4.022233
# 2       X2    3.427188
# 14     X14    3.245704
# 18     X18    3.057642
# 12     X12    2.650176
# 10     X10    2.408881
# 9       X9    2.355874
# 4       X4    2.294482
# 16     X16    1.995297

# %% [markdown]
# ## 15. Save Model

# %%
joblib.dump(model,"catboost_model.joblib")
print("Saved catboost_model.joblib")
# Out:
# Saved catboost_model.joblib

# %% [markdown]
# ## 16. Executive Summary

# %%
print("- CatBoost handles tabular data efficiently.")
print("- Compare its metrics with XGBoost and LightGBM.")
print("- Select the best model for hyperparameter tuning based on F1 and ROC-AUC.")
# Out:
# - CatBoost handles tabular data efficiently.
# - Compare its metrics with XGBoost and LightGBM.
# - Select the best model for hyperparameter tuning based on F1 and ROC-AUC.
