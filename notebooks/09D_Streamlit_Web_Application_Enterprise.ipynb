# %% [markdown]
# # 09D – Streamlit Web Application (Enterprise)
#
# Create an interactive web application for bankruptcy risk prediction.

# %% [markdown]
# ## Business Objective
# Provide business users with a simple interface to submit company financial features and receive real-time bankruptcy risk predictions.

# %%
import streamlit as st
import pandas as pd
import joblib

MODEL_PATH='../models/production_bankruptcy_model.joblib'

model=joblib.load(MODEL_PATH)
df=pd.read_csv('../data/datasets/american_bankruptcy_cleaned.csv')

target='status_label' if 'status_label' in df.columns else 'target'
features=[c for c in df.columns if c not in (target,'company_name')]

st.set_page_config(page_title='Bankruptcy Risk Prediction',layout='wide')
st.title('🏦 Bankruptcy Risk Prediction Dashboard')
st.write('Enter company financial values to predict bankruptcy risk.')
# Out:
# 2026-08-08 11:02:44.640 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-08 11:02:44.642 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-08 11:02:44.734
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/ipykernel_launcher.py [ARGUMENTS]
# 2026-08-08 11:02:44.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-08 11:02:44.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-08 11:02:44.738 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
inputs={}
col1,col2=st.columns(2)

for i,feature in enumerate(features):
    default=float(df[feature].median())
    if i % 2 == 0:
        with col1:
            inputs[feature]=st.number_input(feature,value=default)
    else:
        with col2:
            inputs[feature]=st.number_input(feature,value=default)
# Out:
# 2026-08-08 11:02:44.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-08 11:02:44.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-08 11:02:44.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-08 11:02:44.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-08 11:02:44.753 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-08 11:02:44.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-08 11:02:44.755 Session state does not function when running a script without `streamlit run`
# 2026-08-08 11:02:44.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
if st.button('Predict Bankruptcy Risk'):
    X=pd.DataFrame([inputs])
    pred=int(model.predict(X)[0])
    prob=float(model.predict_proba(X)[0][1])

    if pred==1:
        st.error(f'High Bankruptcy Risk ({prob:.2%})')
    else:
        st.success(f'Low Bankruptcy Risk ({prob:.2%})')

    st.metric('Prediction','Bankrupt' if pred else 'Healthy')
    st.progress(min(max(prob,0.0),1.0))
    st.dataframe(X)
# Out:
# 2026-08-08 11:02:44.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-08 11:02:44.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-08 11:02:44.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-08 11:02:44.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-08 11:02:44.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ## Features
#
# - Interactive input form
# - Real-time predictions
# - Bankruptcy probability
# - Business-friendly output
# - Ready for deployment with Streamlit Cloud or Docker
#
# ### Run Locally
#
# ```bash
# streamlit run app.py
# ```
#
# ## Deliverables
#
# - Streamlit application (`app.py`)
# - Interactive prediction dashboard
# - Production-ready UI
