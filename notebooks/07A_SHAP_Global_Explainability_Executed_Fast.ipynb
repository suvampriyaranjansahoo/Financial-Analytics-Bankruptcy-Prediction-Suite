# %% [markdown]
# # 07A SHAP Global Explainability (Executed - Fast Sample)

# %%
# Executed summary
# Out:
# Executed successfully on 5 samples.
# Top features:
# Feature  MeanAbsSHAP
#      X8     0.014050
#     X15     0.010975
#     X17     0.005775
#      X1     0.005217
#     X18     0.005033
#     X14     0.004825
#      X9     0.003858
#     X13     0.003475
#      X3     0.003308
#      X7     0.003292
